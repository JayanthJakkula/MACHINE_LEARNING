# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt 
df=sns.load_dataset("taxis")
df.head()
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %%
df.describe(include="object")
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6433         6389            6407                   6388
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5451         4577             230                    245
#
#        pickup_borough dropoff_borough
# count            6407            6388
# unique              4               5
# top         Manhattan       Manhattan
# freq             5268            5206

# %%
df.isna().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
(df.shape[0]-df.dropna().shape[0])
# Out:
# 92

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (6341, 14)

# %%
df.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
df.reset_index(drop=True)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6336 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6337 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6338 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6339 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6340 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
#EDA
# tip is the target column 
# tip is numerical feature,analyze with color column which is categorical
df.tip.value_counts()
# Out:
# tip
# 0.00    2244
# 1.00     312
# 2.00     211
# 2.16      89
# 1.86      79
#         ...
# 1.49       1
# 3.99       1
# 0.92       1
# 2.71       1
# 6.62       1
# Name: count, Length: 481, dtype: int64

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
# graphical analysis of categorical data
sns.barplot(x=df["color"],y=df['tip'],estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %% [markdown]
# # barplot
# Yellow tips have higher variability
# Green tips are more consistent  or less  in spread
# # histogram
# Both are right skewed
# yellow has wider spread
# and green concentrated on low tip values

# %%
sns.barplot(x=df["color"],y=df['tip'],estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sns.histplot(x=df.tip,hue=df.color,kde=True,palette=['yellow','green'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# **Hypotheses:**
# ->H0:distribution of tip for yellow=distribution of tip for green
# ->H1:distribution of tip for yellow!=distribution of tip for green

# %%
yellow_tip=df['tip'].loc[df['color']=='yellow']
green_tip=df['tip'].loc[df['color']=='green']
yellow_tip.shape
green_tip.shape
# Out:
# (968,)

# %%
# Independent T-Test
from scipy import stats

t_stat, p_val = stats.ttest_ind(yellow_tip, green_tip)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
# Out:
# Independent T-Test statistic: 17.05932566128597
# P-value: 7.791088119489453e-64

# %%
alpha=0.5
if p_val<alpha:
    print("Reject null hypothesis:tip for yellow category differ from green")
else:
    print("fail to reject null hypothesis")
# Out:
# Reject null hypothesis:tip for yellow category differ from green

# %%
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
sns.barplot(x=df['payment'],y=df['tip'],estimator='mean')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.histplot(x=df.tip,hue=df.payment,kde=True,palette=['yellow','green'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.barplot(x='payment',y='tip',data=df,estimator='std')
plt.subplot(1,2,2)
sns.histplot(x=df.tip,hue=df.payment,kde=True,palette=['yellow','green'])
plt.show()
# Independent T-Test
a=df['tip'].loc[df['payment']=='credit card']
b=df['tip'].loc[df['payment']=='cash']
from scipy import stats
t_stat, p_val = stats.ttest_ind(a,b)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
alpha=0.5
if p_val<alpha:
    print("Reject null hypothesis: i.e tip for credit card category differ from cash")
else:
    print("fail to reject null hypothesis")
# Out:
# Independent T-Test statistic: 49.09538452722153
# P-value: 0.0
# Reject null hypothesis: i.e tip for credit card category differ from cash

# %% [markdown]
# **Hypotheses:**
# ->H0:distribution of tip for credit card=distribution of tip for cash
# ->H1:distribution of tip for credit casd!=distribution of tip for cash

# %%
df.pickup_borough.value_counts()
# Out:
# pickup_borough
# Manhattan    5226
# Queens        638
# Brooklyn      378
# Bronx          99
# Name: count, dtype: int64

# %%
sns.countplot(x=df['pickup_borough'],palette='Set2')
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\4159964779.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['pickup_borough'],palette='Set2')
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %%
sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\2462997792.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.979127
# Manhattan    1.945597
# Queens       3.066458
# Name: tip, dtype: float64

# %%
sns.histplot(hue=df['pickup_borough'],x=df['tip'],bins=20,kde=True)
plt.show()

# %% [markdown]
# ** hypothesis:**
# ->H0: distribution of tip is same across all pickup_borough categories
# ->H1: At least one category has a different distribution of tip

# %%
manhattan_tip=df['tip'][df['pickup_borough']=='Manhattan']
Queens_tip=df['tip'][df['pickup_borough']=='Queens']
Bronx_tip=df['tip'][df['pickup_borough']=='Bronx']
Brooklyn_tip=df['tip'][df['pickup_borough']=='Brooklyn']

# %%
# ANOVA Test

f_stat, p_val = stats.f_oneway(manhattan_tip,Queens_tip,Bronx_tip,Brooklyn_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis: No significant difference by Region")
# Out:
# ANOVA F-statistic: 91.5793383185057
# P-value: 5.155109332422435e-58
# Reject null hypothesis:

# %% [markdown]
# ** hypothesis for Tukey test(for each pair of grops)
# ->H0: distribution of group1=grop2
# ->H1: group1!=group2

# %%
# Tukey HSD Test
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey HSD
tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.pickup_borough, alpha=0.05)
print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
df.dropoff_borough.value_counts()
# Out:
# dropoff_borough
# Manhattan        5172
# Queens            534
# Brooklyn          497
# Bronx             136
# Staten Island       2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['dropoff_borough'],y=df['tip'],palette='Set2',estimator='std')
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\1108502725.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'],y=df['tip'],palette='Set2',estimator='std')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['dropoff_borough']).std()
# Out:
# dropoff_borough
# Bronx            1.788795
# Brooklyn         2.896229
# Manhattan        2.052074
# Queens           3.947016
# Staten Island    2.976920
# Name: tip, dtype: float64

# %%
sns.histplot(x=df['tip'],hue=df['dropoff_borough'],bins=20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
manhattan_tip=df['tip'][df['dropoff_borough']=='Manhattan']
Queens_tip=df['tip'][df['dropoff_borough']=='Queens']
Bronx_tip=df['tip'][df['dropoff_borough']=='Bronx']
Brooklyn_tip=df['tip'][df['dropoff_borough']=='Brooklyn']
Staten_tip=df['tip'][df['dropoff_borough']=='State Island']
groups = [manhattan_tip, Brooklyn_tip, Queens_tip, Bronx_tip, Staten_tip]
groups = [g.dropna() for g in groups if len(g.dropna()) > 1]

# %%
f_stat, p_val = stats.f_oneway(*groups)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis: No significant difference by Region")
# Out:
# ANOVA F-statistic: 23.789814007971167
# P-value: 2.637820690210475e-15
# Reject null hypothesis:

# %%
df.pickup_zone.value_counts()
# Out:
# pickup_zone
# Midtown Center                  227
# Penn Station/Madison Sq West    209
# Clinton East                    208
# Upper East Side South           208
# Midtown East                    196
#                                ...
# Ozone Park                        1
# Glendale                          1
# Woodlawn/Wakefield                1
# West Farms/Bronx River            1
# Hillcrest/Pomonok                 1
# Name: count, Length: 194, dtype: int64

# %%
sns.countplot(x=df['pickup_zone'],palette='Set1')
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\815587650.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['pickup_zone'],palette='Set1')
# <Axes: xlabel='pickup_zone', ylabel='count'>

# %%
## ANOVA Test
categories=[group['tip'].values for name ,group in df.groupby('pickup_zone')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis:")
# Out:
# ANOVA F-statistic: 7.563376210961916
# P-value: 7.892434822136223e-169
# Reject null hypothesis:

# %%
# ANOVA Test
categories=[group['tip'].values for name ,group in df.groupby('dropoff_zone')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis:")
# Out:
# ANOVA F-statistic: 5.76903467327541
# P-value: 1.3107168403745948e-120
# Reject null hypothesis:

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6341                           6341
# mean   2019-03-16 08:30:26.574830080  2019-03-16 08:44:47.525784832
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:28:20            2019-03-08 15:54:00
# 50%              2019-03-15 21:57:47            2019-03-15 22:07:48
# 75%              2019-03-23 17:45:29            2019-03-23 17:57:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare          tip        tolls  \
# count  6341.000000  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931     1.972703     0.314793
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# ...

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
sns.histplot(x=df['tip'],kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(x=df['passengers'],kde=True)
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sns.scatterplot(x=df.tip,y=df.passengers)
plt.show()

# %%
r,p_val=stats.spearmanr(df['tip'],df['passengers'])
print("correaltion:",r)
print("P_value:",p_val)
if p_val<0.5:
    print("REject null hypothesis : there is no relation ")
else:
    print("fail to reject H0")
# Out:
# correaltion: 0.027509812818779178
# P_value: 0.028480753176042872
# REject null hypothesis : there is no relation

# %%
sns.histplot(x=df['fare'],kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.scatterplot(x=df.tip,y=df.fare)
plt.show()

# %%
r,p_val=stats.spearmanr(df['tip'],df['fare'])
print("correaltion:",r)
print("P_value:",p_val)
if p_val<0.5:
    print("REject null hypothesis : there is no relation ")
else:
    print("fail to reject H0")
# Out:
# correaltion: 0.310254279563729
# P_value: 1.5556730728881364e-141
# REject null hypothesis : there is no relation

# %%
sns.histplot(x=df['tolls'],kde=True)
plt.show()

sns.scatterplot(x=df.tip,y=df.tolls)
plt.show()



r,p_val=stats.spearmanr(df['tip'],df['tolls'])
print("correaltion:",r)
print("P_value:",p_val)
if p_val<0.5:
    print("REject null hypothesis : there is no relation ")
else:
    print("fail to reject H0")
# Out:
# correaltion: 0.175380002891528
# P_value: 5.643276180955435e-45
# REject null hypothesis : there is no relation

# %%
sns.histplot(x=df['distance'],kde=True)
plt.show()

sns.scatterplot(x=df.tip,y=df.distance)
plt.show()



r,p_val=stats.spearmanr(df['tip'],df['distance'])
print("correaltion:",r)
print("P_value:",p_val)
if p_val<0.5:
    print("REject null hypothesis : there is no relation ")
else:
    print("fail to reject H0")
# Out:
# correaltion: 0.29265085410043695
# P_value: 1.9411181331374707e-125
# REject null hypothesis : there is no relation

# %%
sns.histplot(x=df['total'],kde=True)
plt.show()

sns.scatterplot(x=df.tip,y=df.total)
plt.show()



r,p_val=stats.spearmanr(df['tip'],df['total'])
print("correaltion:",r)
print("P_value:",p_val)
if p_val<0.5:
    print("REject null hypothesis : there is no relation ")
else:
    print("fail to reject H0")
# Out:
# correaltion: 0.5028299699182296
# P_value: 0.0
# REject null hypothesis : there is no relation

# %%
nm=df[['passengers','fare','distance','tolls','total']]
sns.heatmap(nm.corr(),annot=True)
# Out:
# <Axes: >

# %%
df['pickup'].dt.day
# Out:
# 0       23
# 1        4
# 2       27
# 3       10
# 4       30
#         ..
# 6428    31
# 6429    31
# 6430    23
# 6431     4
# 6432    13
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 6428    3
# 6429    3
# 6430    3
# 6431    3
# 6432    3
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.year
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 6428    2019
# 6429    2019
# 6430    2019
# 6431    2019
# 6432    2019
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.day_name()
# Out:
# 0        Saturday
# 1          Monday
# 2       Wednesday
# 3          Sunday
# 4        Saturday
#           ...
# 6428       Sunday
# 6429       Sunday
# 6430     Saturday
# 6431       Monday
# 6432    Wednesday
# Name: pickup, Length: 6341, dtype: object

# %%
df['pickup_month']=df['pickup'].dt.day
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\3638718681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pickup_month']=df['pickup'].dt.day

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough  pickup_month
# 0    UN/Turtle Bay South      Manhattan       Manhattan            23
# ...

# %%
df.drop(columns='pickup_month')
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df['pickup_month']=df['pickup'].dt.month
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\1560738483.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pickup_month']=df['pickup'].dt.month

# %%
df['pickup_day']=df['pickup'].dt.day
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\1990925589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pickup_day']=df['pickup'].dt.day

# %%
df['pickup_year']=df['pickup'].dt.year
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\2021248856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pickup_year']=df['pickup'].dt.year

# %%
df.pickup_month.value_counts()
# Out:
# pickup_month
# 3    6340
# 2       1
# Name: count, dtype: int64

# %%
df['pickup_month']=df['pickup'].dt.month_name()
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\212731674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pickup_month']=df['pickup'].dt.month_name()

# %%
df.drop(columns='pickup_month')
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df['pickup_month']=df['pickup'].dt.month_name()
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\212731674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pickup_month']=df['pickup'].dt.month_name()

# %%
df['pickup_dayname']=df['pickup'].dt.day_name()
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\3502731189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pickup_dayname']=df['pickup'].dt.day_name()

# %%
df['pickup_hour']=df['pickup'].dt.hour
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\2999649667.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pickup_hour']=df['pickup'].dt.hour

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough pickup_month  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan        March
# ...

# %%
df['dropoff'].dt.day
# Out:
# 0       23
# 1        4
# 2       27
# 3       10
# 4       30
#         ..
# 6428    31
# 6429    31
# 6430    23
# 6431     4
# 6432    13
# Name: dropoff, Length: 6341, dtype: int32

# %%
df['dropoff']
# Out:
# 0      2019-03-23 20:27:24
# 1      2019-03-04 16:19:00
# 2      2019-03-27 18:00:25
# 3      2019-03-10 01:49:51
# 4      2019-03-30 13:37:14
#                ...
# 6428   2019-03-31 09:55:27
# 6429   2019-03-31 18:34:23
# 6430   2019-03-23 23:14:25
# 6431   2019-03-04 10:14:29
# 6432   2019-03-13 19:48:02
# Name: dropoff, Length: 6341, dtype: datetime64[ns]

# %%
df['dropoff'].dt.year
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 6428    2019
# 6429    2019
# 6430    2019
# 6431    2019
# 6432    2019
# Name: dropoff, Length: 6341, dtype: int32

# %%
df['dropoff_month']=df['dropoff'].dt.month_name()
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\2635588911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dropoff_month']=df['dropoff'].dt.month_name()

# %%
df['dropoff_year']=df['dropoff'].dt.year
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\2439667390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dropoff_year']=df['dropoff'].dt.year

# %%
df['dropoff_dayname']=df['dropoff'].dt.day_name()
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\3045995800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dropoff_dayname']=df['dropoff'].dt.day_name()

# %%
df['dropoff_hour']=df['dropoff'].dt.hour
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\2033959495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dropoff_hour']=df['dropoff'].dt.hour

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6341 entries, 0 to 6432
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6341 non-null   datetime64[ns]
#  1   dropoff          6341 non-null   datetime64[ns]
#  2   passengers       6341 non-null   int64
#  3   distance         6341 non-null   float64
#  4   fare             6341 non-null   float64
#  5   tip              6341 non-null   float64
#  6   tolls            6341 non-null   float64
#  7   total            6341 non-null   float64
#  8   color            6341 non-null   object
#  9   payment          6341 non-null   object
#  10  pickup_zone      6341 non-null   object
#  11  dropoff_zone     6341 non-null   object
#  12  pickup_borough   6341 non-null   object
#  13  dropoff_borough  6341 non-null   object
#  14  pickup_month     6341 non-null   object
#  15  pickup_day       6341 non-null   int32
# ...

# %%
df.shape
# Out:
# (6341, 23)

# %%
df['dropoff_day']=df['dropoff'].dt.day
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\2266340454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dropoff_day']=df['dropoff'].dt.day

# %%
df.shape
# Out:
# (6341, 24)

# %%
df['pickup_month'].unique()
# Out:
# array(['March', 'February'], dtype=object)

# %%
sns.barplot(x=df['pickup_month'],y=df['tip'],estimator='mean')
# Out:
# <Axes: xlabel='pickup_month', ylabel='tip'>

# %%
sns.histplot(x=df.tip,hue=df.pickup_month,kde=True,palette='Set2')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#Hypothesis: H0: tips in fedruary =march
# H1: if they are not equal
febraury_tip=df['tip'].loc[df['pickup_month']=='February']
march_tip=df['tip'].loc[df['pickup_month']=='March']
# Independent T-Test
from scipy import stats

t_stat, p_val = stats.ttest_ind(febraury_tip, march_tip)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)
if p_val<0.5:
    print("reject H0: tips in both months are differ")
else:
    print("fail to reject H0")
# Out:
# Independent T-Test statistic: -0.8352658713084974
# P-value: 0.4035995080184128
# reject H0: tips in both months are differ

# %%
df['dropoff_month'].unique()
# Out:
# array(['March', 'April', 'February'], dtype=object)

# %%
#Hypothesis in dropoff_month: H0: tips in fedruary =march
# H1: if they are not equal
febraury_tip=df['tip'].loc[df['dropoff_month']=='February']
march_tip=df['tip'].loc[df['dropoff_month']=='March']
April_tip=df['tip'].loc[df['dropoff_month']=='April']
# ANOVA Test

f_stat, p_val = stats.f_oneway(febraury_tip,march_tip,April_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis: No significant difference by Region")
# Out:
# ANOVA F-statistic: 0.6977458764114044
# P-value: 0.4977441577891454
# Fail to reject null hypothesis: No significant difference by Region

# %%
df['pickup_day'].unique()
# Out:
# array([23,  4, 27, 10, 30, 11, 26,  8, 16, 20, 18, 19, 15, 25, 21, 28, 24,
#         3,  6,  1, 17, 22,  7, 14, 13,  5,  9,  2, 31, 12, 29],
#       dtype=int32)

# %%
df['pickup_dayname'].unique()
# Out:
# array(['Saturday', 'Monday', 'Wednesday', 'Sunday', 'Tuesday', 'Friday',
#        'Thursday'], dtype=object)

# %%
sns.histplot(hue=df['pickup_dayname'],x=df['tip'],bins=20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# ANOVA Test
# H1: if they are not equal
sunday_tip=df['tip'].loc[df['pickup_dayname']=='Sunday']
monday_tip=df['tip'].loc[df['pickup_dayname']=='Monday']
tueday_tip=df['tip'].loc[df['pickup_dayname']=='Tuesday']
wedday_tip=df['tip'].loc[df['pickup_dayname']=='Wednesday']
thueday_tip=df['tip'].loc[df['pickup_dayname']=='Thursday']
wedday_tip=df['tip'].loc[df['pickup_dayname']=='Friday']
satday_tip=df['tip'].loc[df['pickup_dayname']=='Saturday']
f_stat, p_val = stats.f_oneway(sunday_tip,monday_tip,tueday_tip,wedday_tip,thueday_tip,febraury_tip,satday_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: ")
else:
    print("Fail to reject null hypothesis: No significant difference by Region")
# Out:
# ANOVA F-statistic: 1.210206061011029
# P-value: 0.2975546786336295
# Fail to reject null hypothesis: No significant difference by Region

# %%
drop_list=['pickup','dropoff','pickup_day','dropoff_month','pickup_day','pickup_year','dropoff_day','dropoff_year']
df.drop(columns=drop_list,inplace=True)
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\2729466542.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=drop_list,inplace=True)

# %%
df.drop(columns='pickup_month',inplace=True)
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\829841988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='pickup_month',inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cat=['color','payment','pickup_borough','dropoff_borough','pickup_zone','dropoff_zone','pickup_dayname','dropoff_dayname']
for i in cat:
    df[i]=le.fit_transform(df[i])
df.head()
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\893240089.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=le.fit_transform(df[i])
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\893240089.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]=le.fit_transform(df[i])
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\893240089.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.preprocessing import StandardScaler
cont=['distance','tolls','total','fare']
scaler=StandardScaler()
df[cont]=scaler.fit_transform(df[cont])
df.head()
# Out:
# C:\Users\jakku\AppData\Local\Temp\ipykernel_22516\523591358.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cont]=scaler.fit_transform(df[cont])
#    passengers  distance      fare   tip     tolls     total  color  payment  \
# 0           1 -0.375780 -0.549175  2.15 -0.229932 -0.413941      1        1
# 1           1 -0.593552 -0.735718  0.00 -0.229932 -0.695808      1        0
# 2           1 -0.437617 -0.502540  2.36 -0.229932 -0.320500      1        1
# 3           1  1.264233  1.316252  6.15 -0.229932  1.439435      1        1
# 4           3 -0.225221 -0.362633  1.10 -0.229932 -0.379190      1        1
#
#    pickup_zone  dropoff_zone  pickup_borough  dropoff_borough  pickup_dayname  \
# ...

# %%
x=df.drop('tip',axis=1)
y=df['tip']
x.shape
# Out:
# (6341, 15)

# %%
y.shape
# Out:
# (6341,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print("X_train shape :",x_train.shape)
print("Y_Train shape:",y_train.shape)
print("X test shape :",x_test.shape)
print("Y test shape:",y_test.shape)
# Out:
# X_train shape : (5072, 15)
# Y_Train shape: (5072,)
# X test shape : (1269, 15)
# Y test shape: (1269,)

# %%
from sklearn.linear_model import LinearRegression
m=LinearRegression()
m.fit(x_train,y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
m.coef_
# Out:
# array([-1.00960729e-02,  1.18137138e-01, -7.85417376e+00, -9.59105834e-01,
#         9.67146005e+00, -1.19693094e+00,  5.58103018e-01, -8.28840049e-04,
#        -1.54397768e-03,  2.18833421e-01, -7.94129774e-02,  7.39871519e-03,
#        -1.55568520e-02, -1.23446085e-02, -1.98943019e-03])

# %%
m.intercept_
# Out:
# np.float64(2.8421062423242667)

# %% [markdown]
# Training SCore

# %%
y_train_pred=m.predict(x_train)
train_score=m.score(x_train,y_train)
print("Model Training score :",train_score)
# Out:
# Model Training score : 0.9240926502797042

# %%
y_test_pred=m.predict(x_test)
test_score=m.score(x_test,y_test)
print("Model Training score :",test_score)
# Out:
# Model Training score : 0.925082783700895

# %%
from sklearn.metrics import root_mean_squared_error,mean_absolute_error,r2_score
root_mean_squared_error(y_train,y_train_pred)
# Out:
# 0.6551099087071314

# %%
mean_absolute_error(y_train,y_train_pred)
# Out:
# 0.4388777161076765

# %%
print("MAE for train :",mean_absolute_error(y_train,y_train_pred))
print("r2_score for train:",r2_score(y_train,y_train_pred))
# Out:
# MAE for train : 0.4388777161076765
# r2_score for train: 0.9240926502797042

# %%
print("RMSE for test :",root_mean_squared_error(y_test,y_test_pred))
print("MSE for test :",mean_absolute_error(y_test,y_test_pred))
print("MAE for test :",mean_absolute_error(y_test,y_test_pred))
print("r2_score for test :",r2_score(y_test,y_test_pred))
# Out:
# RMSE for test : 0.6285208338155888
# MSE for test : 0.4208490692090648
# MAE for test : 0.4208490692090648
# r2_score for test : 0.925082783700895
